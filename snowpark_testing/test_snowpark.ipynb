# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import *
from snowflake.snowpark.functions import col, lit
import getpass
import pandas as pd
import json
from get_secret import get_secret

# %%
connection_parameters = json.loads(get_secret())
connection_parameters.update({'warehouse':'COMPUTE_WH', 'database':'ANALYTICS_PROD','schema': 'IOATAWARE',"loglevel":'DEBUG'})
session = Session.builder.configs(connection_parameters).create()

# %%
print(f"Current Database and schema: {session.get_fully_qualified_current_schema()}")
print(f"Current Warehouse: {session.get_current_warehouse()}")
# Out:
# Current Database and schema: "ANALYTICS_PROD"."IOATAWARE"
# Current Warehouse: "COMPUTE_WH"

# %% [markdown]
# # Import and clean snowflake views

# %%
view_name = "VW_AIF_REPORT_DETAIL"
flight_date = "2023/06/03"
flight_id = 111554

# %%
snowpark_df = session.table(view_name)
snowflake_pd_df = snowpark_df.filter((snowpark_df['Flight Date'] == flight_date) & (snowpark_df["Flight ID"] == flight_id)).to_pandas()
#snowflake_pd_df = snowflake_pd_df[snowflake_pd_df['Flight Date'] == flight_date & snowflake_pd_df["Flight ID"] == flight_id]

# %%
snowflake_pd_df['combined_timestamp'] = pd.to_datetime(snowflake_pd_df['Flight Date'] + ' ' + snowflake_pd_df['Flight time'])
snowflake_pd_df['combined_timestamp_mt'] = snowflake_pd_df['combined_timestamp'].dt.tz_localize('UTC').dt.tz_convert('US/Mountain')
snowflake_pd_df['Flight Date'] = snowflake_pd_df['combined_timestamp_mt'].dt.date

# %%
snowflake_pd_df['combined_timestamp'] = pd.to_datetime(snowflake_pd_df['Flight Date'] + ' ' + snowflake_pd_df['Flight time'])
snowflake_pd_df['combined_timestamp_mt'] = snowflake_pd_df['combined_timestamp'].dt.tz_localize('UTC').dt.tz_convert('US/Mountain')
snowflake_pd_df['Flight Date'] = snowflake_pd_df['combined_timestamp_mt'].dt.date

# %%
snowflake_pd_df.dtypes
# Out:
# Flight Date                                   object
# Flight time                                   object
# Flight ID                                      int32
# Departure                                     object
# Arrival                                       object
# Reservation Number                             int32
# Leg Number                                      int8
# PNR                                           object
# Check In Boarded                              object
# Status                                        object
# First Name                                    object
# Last Name                                     object
# Charge Type                                   object
# Net Charge                                    object
# Leg Start                                     object
# Leg End                                       object
# Charge Date                                   object
# combined_timestamp                    datetime64[ns]
# combined_timestamp_mt    datetime64[ns, US/Mountain]
# dtype: object

# %%
#Remove the column we are not testing for now

# %%
columns_to_remove = ['First Name','Flight ID', 'Last Name','Charge Date', 'combined_timestamp','combined_timestamp_mt','Flight time']
snowflake_pd_df = snowflake_pd_df.drop(columns=columns_to_remove)
snowflake_pd_df['Flight Date'] = pd.to_datetime(snowflake_pd_df['Flight Date'])
snowflake_pd_df['Reservation Number'] = snowflake_pd_df['Reservation Number'].astype(int)
snowflake_pd_df['Leg Number'] = snowflake_pd_df['Leg Number'].astype(int)
snowflake_pd_df['Net Charge'] = snowflake_pd_df['Net Charge'].astype(float)

# %%
snowflake_pd_df
# Out:
#     Flight Date Departure Arrival  Reservation Number  Leg Number     PNR  \
# 0    2023-06-03     YYC     YYZ               5024160           1  T7PXE2
# 1    2023-06-03     YYC     YYZ               7291116           2  ZJZQ3N
# 2    2023-06-03     YYC     YYZ               7346621           2  CATTCF
# 3    2023-06-03     YYC     YYZ               7659990           1  QW3FAF
# 4    2023-06-03     YYC     YYZ               4673871           2  CFD22S
# ..          ...       ...     ...                 ...         ...     ...
# 150  2023-06-03     YYC     YYZ               7493237           1  ZUKAQ4
# 151  2023-06-03     YYC     YYZ               7291116           2  ZJZQ3N
# 152  2023-06-03     YYC     YYZ               7284065           1  FXP4K5
# 153  2023-06-03     YYC     YYZ               5477840           1  4NZUKN
# 154  2023-06-03     YYC     YYZ               7478451           1  KKEUV2
#
#     Check In Boarded Status              Charge Type  Net Charge Leg Start  \
# 0                  B      C  Airport Improvement Fee        35.0     YYC
# 1                  B      C  Airport Improvement Fee        35.0     YYC
# 2                  B      C  Airport Improvement Fee        35.0     YYC
# 3                  B      C  Airport Improvement Fee        35.0     YYC
# 4                  B      C  Airport Improvement Fee        35.0     YYC
# ..               ...    ...                      ...         ...       ...
# 150                B      C  Airport Improvement Fee        35.0     YYC
# 151                B      C  Airport Improvement Fee        35.0     YYC
# 152                B      C  Airport Improvement Fee        35.0     YYC
# 153                B      C  Airport Improvement Fee        35.0     YYC
# 154                B      C  Airport Improvement Fee        35.0     YYC
#
#     Leg End
# 0     YYZ
# 1     YYZ
# 2     YYZ
# 3     YYZ
# 4     YYZ
# ..      ...
# 150   YYZ
# 151   YYZ
# 152   YYZ
# 153   YYZ
# 154   YYZ
#
# [155 rows x 12 columns]

# %%
snowflake_pd_df.dtypes
# Out:
# Flight Date           datetime64[ns]
# Departure                     object
# Arrival                       object
# Reservation Number             int32
# Leg Number                     int32
# PNR                           object
# Check In Boarded              object
# Status                        object
# Charge Type                   object
# Net Charge                   float64
# Leg Start                     object
# Leg End                       object
# dtype: object

# %% [markdown]
# # Import and clean report data

# %%
report_df = pd.read_csv('AIF_Report_Detail_111554.csv', skiprows=3)

# %%
report_df.columns
# Out:
# Index(['FlightDate1', 'Departure1', 'Arrival1', 'lng_Reservation_Nmbr',
#        'lng_Leg_Nmbr', 'Reference', 'str_Res_CheckIn_Boarded',
#        'str_Res_Status', 'str_First_Name', 'str_Last_Name',
#        'str_GL_Charge_Type_Desc', 'NetCharge', 'LegDeparture', 'LegArrival',
#        'ChargeDate'],
#       dtype='object')

# %%
report_df.dtypes
# Out:
# FlightDate1                object
# Departure1                 object
# Arrival1                   object
# lng_Reservation_Nmbr        int64
# lng_Leg_Nmbr                int64
# Reference                  object
# str_Res_CheckIn_Boarded    object
# str_Res_Status             object
# str_First_Name             object
# str_Last_Name              object
# str_GL_Charge_Type_Desc    object
# NetCharge                  object
# LegDeparture               object
# LegArrival                 object
# ChargeDate                 object
# dtype: object

# %%
report_df
# Out:
#     FlightDate1 Departure1 Arrival1  lng_Reservation_Nmbr  lng_Leg_Nmbr  \
# 0    2023/06/03      YYC      YYZ                 5166995             2
# 1    2023/06/03      YYC      YYZ                 5401723             1
# 2    2023/06/03      YYC      YYZ                 5397156             2
# 3    2023/06/03      YYC      YYZ                 5401723             1
# 4    2023/06/03      YYC      YYZ                 5401723             1
# ..          ...        ...      ...                   ...           ...
# 150  2023/06/03      YYC      YYZ                 7550127             2
# 151  2023/06/03      YYC      YYZ                 7550127             2
# 152  2023/06/03      YYC      YYZ                 7563605             2
# 153  2023/06/03      YYC      YYZ                 7563605             2
# 154  2023/06/03      YYC      YYZ                 7563605             2
#
#     Reference str_Res_CheckIn_Boarded str_Res_Status str_First_Name  \
# 0      XVXP78                       B              C   MATT GREGORY
# 1      2SDFYX                       B              C     CHUNGYOUNG
# 2      3TKS25                       B              C        UTKARSH
# 3      2SDFYX                       B              C      SEUNGYEOB
# 4      2SDFYX                       B              C        HEESOOK
# ..        ...                     ...            ...            ...
# 150    TNPX9H                       B              C  YAN KWONG IAN
# 151    TNPX9H                       B              C       SIU HONG
# 152    GC6G88                       B              C          MANOJ
# 153    GC6G88                       B              C       SHYAMALI
# 154    GC6G88                       B              C          ARJUN
#
#     str_Last_Name  str_GL_Charge_Type_Desc NetCharge LegDeparture LegArrival  \
# 0      VISITACION  Airport Improvement Fee    $35.00        YYC        YYZ
# 1             LIM  Airport Improvement Fee    $35.00        YYC        YYZ
# 2          SHARMA  Airport Improvement Fee    $35.00        YYC        YYZ
# 3             LIM  Airport Improvement Fee    $35.00        YYC        YYZ
# 4             KIM  Airport Improvement Fee    $35.00        YYC        YYZ
# ..            ...                      ...       ...          ...        ...
# 150          CHAN  Airport Improvement Fee    $35.00        YYC        YYZ
# 151          SUEN  Airport Improvement Fee    $35.00        YYC        YYZ
# 152    CHATTERJEE  Airport Improvement Fee    $35.00        YYC        YYZ
# 153    CHATTERJEE  Airport Improvement Fee    $35.00        YYC        YYZ
# 154        MANDAL  Airport Improvement Fee    $35.00        YYC        YYZ
#
#      ChargeDate
# 0    11/29/2022
# 1    12/29/2022
# 2    12/28/2022
# 3    12/29/2022
# 4    12/29/2022
# ..          ...
# 150   5/16/2023
# 151   5/16/2023
# 152   5/17/2023
# 153   5/17/2023
# 154   5/17/2023
#
# [155 rows x 15 columns]

# %%
columns_to_remove = ['str_First_Name', 'str_Last_Name','ChargeDate']
report_df = report_df.drop(columns=columns_to_remove)

report_df['FlightDate1'] = pd.to_datetime(report_df['FlightDate1'])
report_df['lng_Reservation_Nmbr'] = report_df['lng_Reservation_Nmbr'].astype(int)
report_df['lng_Leg_Nmbr'] = report_df['lng_Leg_Nmbr'].astype(int)
report_df['NetCharge'] = report_df['NetCharge'].str.replace('$', '')
report_df['NetCharge'] = report_df['NetCharge'].str.replace(')', '')
report_df['NetCharge'] = report_df['NetCharge'].str.replace('(', '-')
report_df['NetCharge'] = report_df['NetCharge'].astype(float)

# %% [markdown]
# # Compare two dataframes

# %%
snowflake_pd_df =snowflake_pd_df.drop_duplicates()
#snowflake_pd_df

# %%
report_df = report_df.drop_duplicates()
#report_df

# %%
snowflake_pd_df.columns = report_df.columns

# %%
merged = snowflake_pd_df.merge(report_df, how = 'outer', indicator = True)
snowflake_only = merged[merged['_merge'] == "left_only"]
common = merged[merged['_merge'] == "both"]
report_only = merged[merged['_merge'] == "right_only"]

# %%
common
# Out:
#    FlightDate1 Departure1 Arrival1  lng_Reservation_Nmbr  lng_Leg_Nmbr  \
# 0   2023-06-03      YYC      YYZ                 5024160             1
# 1   2023-06-03      YYC      YYZ                 7291116             2
# 2   2023-06-03      YYC      YYZ                 7346621             2
# 3   2023-06-03      YYC      YYZ                 7659990             1
# 4   2023-06-03      YYC      YYZ                 4673871             2
# ..         ...        ...      ...                   ...           ...
# 87  2023-06-03      YYC      YYZ                 7166918             2
# 88  2023-06-03      YYC      YYZ                 7294824             2
# 89  2023-06-03      YYC      YYZ                 5477840             1
# 90  2023-06-03      YYC      YYZ                 7155627             1
# 91  2023-06-03      YYC      YYZ                 7493237             1
#
#    Reference str_Res_CheckIn_Boarded str_Res_Status  str_GL_Charge_Type_Desc  \
# 0     T7PXE2                       B              C  Airport Improvement Fee
# 1     ZJZQ3N                       B              C  Airport Improvement Fee
# 2     CATTCF                       B              C  Airport Improvement Fee
# 3     QW3FAF                       B              C  Airport Improvement Fee
# 4     CFD22S                       B              C  Airport Improvement Fee
# ..       ...                     ...            ...                      ...
# 87    ASBVKN                       B              C  Airport Improvement Fee
# 88    T4DMNZ                       B              C  Airport Improvement Fee
# 89    4NZUKN                       B              C  Airport Improvement Fee
# 90    XFNGQS                       B              C  Airport Improvement Fee
# 91    ZUKAQ4                       B              C  Airport Improvement Fee
#
#     NetCharge LegDeparture LegArrival _merge
# 0        35.0        YYC        YYZ     both
# 1        35.0        YYC        YYZ     both
# 2        35.0        YYC        YYZ     both
# 3        35.0        YYC        YYZ     both
# 4        35.0        YYC        YYZ     both
# ..        ...          ...        ...    ...
# 87       35.0        YYC        YYZ     both
# 88       35.0        YYC        YYZ     both
# 89       35.0        YYC        YYZ     both
# 90       35.0        YYC        YYZ     both
# 91       35.0        YYC        YYZ     both
#
# [92 rows x 13 columns]

# %%
def calculate_accuracy(df1, df2):
    merged = df1.merge(df2, how = 'outer', indicator = True)
    matched = merged[merged['_merge'] == "both"]

    # Calculate the total number of elements
    total_elements = len(df2)

    # Calculate accuracy as a percentage
    accuracy = (len(matched) / total_elements) * 100

    return accuracy

# %%
accuracy_percentage = calculate_accuracy(snowflake_pd_df, report_df)
print(f"Accuracy: {accuracy_percentage:.2f}%")
# Out:
# Accuracy: 100.00%

# %% [markdown]
# # Output the difference file

# %%
try:
    snowflake_only.to_csv("snowflake_only_record.csv", index=False) 
except:
    print("No snowflake only records")
try:
    report_only.to_csv("report_only_record.csv", index=False) 
except:
    print("No report only records")
# Out:
# No snowflake only records
# No report only records
