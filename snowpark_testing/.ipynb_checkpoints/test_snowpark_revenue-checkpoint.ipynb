# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import *
from snowflake.snowpark.functions import col, lit
import getpass
import pandas as pd
import json
from get_secret import get_secret

# %%
connection_parameters = json.loads(get_secret())
connection_parameters.update({'warehouse':'COMPUTE_WH', 'database':'ANALYTICS_PROD','schema': 'IOATAWARE',"loglevel":'DEBUG'})
session = Session.builder.configs(connection_parameters).create()

# %%
print(f"Current Database and schema: {session.get_fully_qualified_current_schema()}")
print(f"Current Warehouse: {session.get_current_warehouse()}")
# Out:
# Current Database and schema: "ANALYTICS_PROD"."IOATAWARE"
# Current Warehouse: "COMPUTE_WH"

# %% [markdown]
# # Import and clean snowflake views

# %%
view_name = "VW_REVENUE_RAW_DATA"
flight_date = "07/01/2023"
#flight_id = 111554

# %%
snowpark_df = session.table(view_name)

# %%
#snowpark_df = session.table(view_name)
import snowflake.snowpark.functions as F
snowflake_pd_df = snowpark_df.filter(F.col('Flight Date')  == flight_date ).to_pandas()

# %%
#snowflake_pd_df

# %%
snowflake_pd_df['combined_timestamp'] = pd.to_datetime(snowflake_pd_df['Flight Date'] + ' ' + snowflake_pd_df['Flight time'])
snowflake_pd_df['combined_timestamp_mt'] = snowflake_pd_df['combined_timestamp'].dt.tz_localize('UTC').dt.tz_convert('US/Mountain')
snowflake_pd_df['Flight Date'] = snowflake_pd_df['combined_timestamp_mt'].dt.date

# %%
snowflake_pd_df.columns
# Out:
# Index(['Flight Date', 'Reservation Nmbr', 'Sked Detail Id Nmbr', 'Departure',
#        'Arrival', 'Legs Id Nmbr', 'Charge Type', 'Net Charge', 'Taxes',
#        'Total Charge', 'Charge Type Desc', 'Flight Nmbr', 'Charges Desc',
#        'User Id Nmbr', 'Leg Nmbr', 'Segments Id Nmbr', 'Agency Id Nmbr',
#        'Reference', 'Currency Ident', 'Agency Name', 'Transborder',
#        'Leg Status', 'Category', 'Sales Username', 'Ancillary Category',
#        'Purchase Cnt', 'Classification', 'Channel'],
#       dtype='object')

# %%
#snowflake_pd_df.dtypes

# %%
#Remove the column we are not testing for now

# %%
columns_to_remove = ['Charge Date','\tPercent of Full Leg','Flight time','combined_timestamp','combined_timestamp_mt']
snowflake_pd_df = snowflake_pd_df.drop(columns=columns_to_remove)

snowflake_pd_df['Flight Date'] = pd.to_datetime(snowflake_pd_df['Flight Date'])
snowflake_pd_df['Net Charge'] = snowflake_pd_df['Net Charge'].astype(float)
snowflake_pd_df['Taxes'] = snowflake_pd_df['Taxes'].astype(float)
snowflake_pd_df['Total Charge'] = snowflake_pd_df['Total Charge'].astype(float)
snowflake_pd_df['Flight Nmbr'] = snowflake_pd_df['Flight Nmbr'].astype(int)

# %% [markdown]
# # Import and clean report data

# %%
report_df = pd.read_csv('Revenue/Revenue_Raw_Data_0701.csv', skiprows=0)

# %%
report_df.columns
# Out:
# Index(['Source', 'FlightDate1', 'ActualFlightDate', 'lng_Reservation_Nmbr',
#        'lng_Sked_Detail_Id_Nmbr', 'ChargeDate', 'Departure', 'Arrival',
#        'lng_Res_Legs_Id_Nmbr', 'ChargeType', 'NetCharge', 'Taxes',
#        'mny_Tax_1_Percentage', 'TotalCharge', 'str_GL_Charge_Type_Desc',
#        'str_Flight_Nmbr', 'Percent', 'str_GL_Charges_Desc',
#        'lng_Creation_User_Id_Nmbr', 'lng_Leg_Nmbr', 'lng_Res_Segments_Id_Nmbr',
#        'lng_Agency_Id_Nmbr', 'Reference', 'str_Currency_Ident', 'Base_Charge',
#        'Base_Taxes', 'mny_Exchange_Rate', 'TotalCharge1', 'str_Agency_Name',
#        'LastMod_SalesUser', 'Transborder', 'str_Leg_Status', 'Category',
#        'AncillaryCategory', 'PurchaseCnt', 'PositiveChargePAX',
#        'Classification', 'Channel'],
#       dtype='object')

# %%
report_df.head()
# Out:
#    Source FlightDate1 ActualFlightDate  lng_Reservation_Nmbr  \
# 0  Amelia    7/1/2023         7/1/2023               5452981
# 1  Amelia    7/1/2023         7/1/2023               5452981
# 2  Amelia    7/1/2023         7/1/2023               5452981
# 3  Amelia    7/1/2023         7/1/2023               5452981
# 4  Amelia    7/1/2023         7/1/2023               5452981
#
#    lng_Sked_Detail_Id_Nmbr         ChargeDate Departure Arrival  \
# 0                   152583  6/25/2023 1:31 PM     YEG     YVR
# 1                   152583  6/25/2023 2:11 PM     YEG     YVR
# 2                   152583  6/25/2023 2:11 PM     YEG     YVR
# 3                   152583  6/25/2023 1:31 PM     YEG     YVR
# 4                   152583  6/25/2023 2:11 PM     YEG     YVR
#
#    lng_Res_Legs_Id_Nmbr  ChargeType  ... str_Agency_Name  \
# 0              16441187           1  ...   Air Black Box
# 1              16441187           1  ...   Air Black Box
# 2              16441187           1  ...   Air Black Box
# 3              16441187           4  ...   Air Black Box
# 4              16441187           4  ...   Air Black Box
#
#             LastMod_SalesUser Transborder str_Leg_Status  Category  \
# 0  BaseCC-PH - Jacon Olinares    Domestic              C  FlowThru
# 1  BaseCC-PH - Jacon Olinares    Domestic              C  FlowThru
# 2  BaseCC-PH - Jacon Olinares    Domestic              C  FlowThru
# 3  BaseCC-PH - Jacon Olinares    Domestic              C      Base
# 4  BaseCC-PH - Jacon Olinares    Domestic              C      Base
#
#          AncillaryCategory PurchaseCnt PositiveChargePAX  Classification  \
# 0  Airport Improvement Fee           0          18140874       Mid Stage
# 1  Airport Improvement Fee           0                 0       Mid Stage
# 2  Airport Improvement Fee           0          18140874       Mid Stage
# 3                     Fare           0          18140874       Mid Stage
# 4                     Fare           0                 0       Mid Stage
#
#    Channel
# 0   Direct
# 1   Direct
# 2   Direct
# 3   Direct
# 4   Direct
#
# [5 rows x 38 columns]

# %%
report_df.dtypes
# Out:
# Source                       object
# FlightDate1                  object
# ActualFlightDate             object
# lng_Reservation_Nmbr          int64
# lng_Sked_Detail_Id_Nmbr       int64
# ChargeDate                   object
# Departure                    object
# Arrival                      object
# lng_Res_Legs_Id_Nmbr          int64
# ChargeType                    int64
# NetCharge                    object
# Taxes                        object
# mny_Tax_1_Percentage         object
# TotalCharge                  object
# str_GL_Charge_Type_Desc      object
# str_Flight_Nmbr               int64
# Percent                      object
# str_GL_Charges_Desc          object
# lng_Creation_User_Id_Nmbr     int64
# lng_Leg_Nmbr                  int64
# lng_Res_Segments_Id_Nmbr      int64
# lng_Agency_Id_Nmbr            int64
# Reference                    object
# str_Currency_Ident           object
# Base_Charge                  object
# Base_Taxes                   object
# mny_Exchange_Rate             int64
# TotalCharge1                 object
# str_Agency_Name              object
# LastMod_SalesUser            object
# Transborder                  object
# str_Leg_Status               object
# Category                     object
# AncillaryCategory            object
# PurchaseCnt                   int64
# PositiveChargePAX             int64
# Classification               object
# Channel                      object
# dtype: object

# %%
columns_to_remove = ['Source','ActualFlightDate','mny_Tax_1_Percentage','Percent', 'ChargeDate', 'Base_Charge','Base_Taxes','TotalCharge1','mny_Exchange_Rate','PositiveChargePAX']
report_df = report_df.drop(columns=columns_to_remove)

report_df['NetCharge'] = report_df['NetCharge'].str.replace('$', '')
report_df['NetCharge'] = report_df['NetCharge'].str.replace(')', '')
report_df['NetCharge'] = report_df['NetCharge'].str.replace('(', '-')
report_df['NetCharge'] = report_df['NetCharge'].astype(float)

report_df['Taxes'] = report_df['Taxes'].str.replace('$', '')
report_df['Taxes'] = report_df['Taxes'].str.replace(')', '')
report_df['Taxes'] = report_df['Taxes'].str.replace('(', '-')
report_df['Taxes'] = report_df['Taxes'].astype(float)

report_df['TotalCharge'] = report_df['TotalCharge'].str.replace('$', '')
report_df['TotalCharge'] = report_df['TotalCharge'].str.replace(')', '')
report_df['TotalCharge'] = report_df['TotalCharge'].str.replace('(', '-')
report_df['TotalCharge'] = report_df['TotalCharge'].astype(float)

#report_df['Percent'] = report_df['Percent'].str.replace('%', '')
report_df['mny_Exchange_Rate'] = report_df['mny_Exchange_Rate'].astype(float)
report_df['FlightDate1'] = pd.to_datetime(report_df['FlightDate1'])

# %% [markdown]
# # Compare two dataframes

# %%
snowflake_pd_df =snowflake_pd_df.drop_duplicates()
snowflake_pd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 173206 entries, 0 to 174305
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Flight Date          173206 non-null  datetime64[ns]
#  1   Reservation Nmbr     173206 non-null  int32
#  2   Sked Detail Id Nmbr  173206 non-null  int32
#  3   Departure            173206 non-null  object
#  4   Arrival              173206 non-null  object
#  5   Legs Id Nmbr         173206 non-null  int32
#  6   Charge Type          173206 non-null  int16
#  7   Net Charge           173206 non-null  float64
#  8   Taxes                173206 non-null  float64
#  9   Total Charge         173206 non-null  float64
#  10  Charge Type Desc     173206 non-null  object
#  11  Flight Nmbr          173206 non-null  int32
#  12  Charges Desc         173206 non-null  object
#  13  User Id Nmbr         173206 non-null  int16
#  14  Leg Nmbr             173206 non-null  int8
#  15  Segments Id Nmbr     173206 non-null  int32
#  16  Agency Id Nmbr       173206 non-null  int16
#  17  Reference            173206 non-null  object
#  18  Currency Ident       173206 non-null  object
#  19  Agency Name          173206 non-null  object
#  20  Transborder          173206 non-null  object
#  21  Leg Status           173206 non-null  object
#  22  Category             173206 non-null  object
#  23  Sales Username       173206 non-null  object
#  24  Ancillary Category   173206 non-null  object
#  25  Purchase Cnt         173206 non-null  int8
#  26  Classification       173206 non-null  object
#  27  Channel              173206 non-null  object
# dtypes: datetime64[ns](1), float64(3), int16(3), int32(5), int8(2), object(14)
# memory usage: 29.7+ MB

# %%
report_df = report_df.drop_duplicates()
report_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83955 entries, 0 to 85787
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FlightDate1                83955 non-null  datetime64[ns]
#  1   lng_Reservation_Nmbr       83955 non-null  int64
#  2   lng_Sked_Detail_Id_Nmbr    83955 non-null  int64
#  3   Departure                  83955 non-null  object
#  4   Arrival                    83955 non-null  object
#  5   lng_Res_Legs_Id_Nmbr       83955 non-null  int64
#  6   ChargeType                 83955 non-null  int64
#  7   NetCharge                  83955 non-null  float64
#  8   Taxes                      83955 non-null  float64
#  9   TotalCharge                83955 non-null  float64
#  10  str_GL_Charge_Type_Desc    83955 non-null  object
#  11  str_Flight_Nmbr            83955 non-null  int64
#  12  str_GL_Charges_Desc        83955 non-null  object
#  13  lng_Creation_User_Id_Nmbr  83955 non-null  int64
#  14  lng_Leg_Nmbr               83955 non-null  int64
#  15  lng_Res_Segments_Id_Nmbr   83955 non-null  int64
#  16  lng_Agency_Id_Nmbr         83955 non-null  int64
#  17  Reference                  83955 non-null  object
#  18  str_Currency_Ident         83955 non-null  object
#  19  mny_Exchange_Rate          83955 non-null  float64
#  20  str_Agency_Name            83955 non-null  object
#  21  Transborder                83955 non-null  object
#  22  str_Leg_Status             83955 non-null  object
#  23  Category                   83955 non-null  object
#  24  AncillaryCategory          83955 non-null  object
#  25  PurchaseCnt                83955 non-null  int64
#  26  Classification             83955 non-null  object
#  27  Channel                    83955 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(10), object(13)
# memory usage: 18.6+ MB

# %%
report_df.columns = snowflake_pd_df.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[444], line 1
# ----> 1 report_df.columns = snowflake_pd_df.columns
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\pandas\core\generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\pandas\core\generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# --> 730 self._mgr.set_axis(axis, labels)
#     731 self._clear_item_cache()
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\pandas\core\internals\managers.py:225, in BaseBlockManager.set_axis(self, axis, new_labels)
#     223 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224     # Caller is responsible for ensuring we have an Index object.
# --> 225     self._validate_set_axis(axis, new_labels)
#     226     self.axes[axis] = new_labels
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 30 elements, new values have 28 elements

# %%
report_df = report_df.astype(snowflake_pd_df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[445], line 1
# ----> 1 report_df = report_df.astype(snowflake_pd_df.dtypes)
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\pandas\core\generic.py:6290, in NDFrame.astype(self, dtype, copy, errors)
#    6288 for col_name in dtype_ser.index:
#    6289     if col_name not in self:
# -> 6290         raise KeyError(
#    6291             "Only a column name can be used for the "
#    6292             "key in a dtype mappings argument. "
#    6293             f"'{col_name}' not found in columns."
#    6294         )
#    6296 dtype_ser = dtype_ser.reindex(self.columns, fill_value=None, copy=False)
#    6298 results = []
#
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'Flight Date' not found in columns."

# %%
merged = snowflake_pd_df.merge(report_df, how = 'outer', indicator = True)
snowflake_only = merged[merged['_merge'] == "left_only"]
common = merged[merged['_merge'] == "both"]
report_only = merged[merged['_merge'] == "right_only"]

# %%
common
# Out:
#         Source Flight Date  Reservation Nmbr  Sked Detail Id Nmbr Departure  \
# 0       Amelia  2023-07-01           7871670               116595     YEG
# 2       Amelia  2023-07-01           7898074               119901     YEG
# 7       Amelia  2023-07-01           7806899               148928     YYZ
# 8       Amelia  2023-07-01           7805447               112911     YYZ
# 10      Amelia  2023-07-01           7119505               127170     YKF
# ...        ...         ...               ...                  ...       ...
# 183992  Amelia  2023-07-01           7142252               109136     YVR
# 184001  Amelia  2023-07-01           7974080               118171     YEG
# 184005  Amelia  2023-07-01           6060939               129176     YLW
# 184006  Amelia  2023-07-01           5408575               115474     YYZ
# 184007  Amelia  2023-07-01           6824207               109785     YYZ
#
#        Arrival  Legs Id Nmbr  Charge Type  Net Charge  Taxes  ...  \
# 0        YXX        16168922            5        7.12   0.36  ...
# 2        YVR        16224434            4       71.21   3.56  ...
# 7        YYG        16034645            1       35.00   4.55  ...
# 8        YEG        16031514            1       35.00   4.55  ...
# 10       CUN        14665587            1       15.00   1.95  ...
# ...        ...           ...          ...         ...    ...  ...
# 183992   YYZ        14713882            1       25.00   1.25  ...
# 184001   YOW        16382097            4      147.40   7.37  ...
# 184005   YWG        12432671            5        7.12   0.36  ...
# 184006   YSJ        10940759            5        7.12   0.93  ...
# 184007   YVR        14014992         1001       25.00   3.25  ...
#
#                Agency Name                   Sale_Username    Transborder  \
# 0            Air Black Box                          ABBAPI       Domestic
# 2            Air Black Box                          ABBAPI       Domestic
# 7            Air Black Box                          ABBAPI       Domestic
# 8            Air Black Box                          ABBAPI       Domestic
# 10           Air Black Box                          ABBAPI  International
# ...                    ...                             ...            ...
# 183992  API - Travelfusion                 TRAVELFUSION-F8       Domestic
# 184001       Air Black Box                          ABBAPI       Domestic
# 184005           Flair Air  BaseCC-PH - Anne Juliette Bell       Domestic
# 184006       Air Black Box                          ABBAPI       Domestic
# 184007       Air Black Box                          ABBAPI       Domestic
#
#        Leg Status   Category              AncillaryCategory  PurchaseCnt  \
# 0               C   FlowThru  Air Traveller Security Charge            0
# 2               C       Base                           Fare            0
# 7               C   FlowThru        Airport Improvement Fee            0
# 8               C   FlowThru        Airport Improvement Fee            0
# 10              C   FlowThru        Airport Improvement Fee            0
# ...           ...        ...                            ...          ...
# 183992          C   FlowThru        Airport Improvement Fee            0
# 184001          C       Base                           Fare            0
# 184005          X   FlowThru  Air Traveller Security Charge            0
# 184006          C   FlowThru  Air Traveller Security Charge            0
# 184007          C  Ancillary                Seat Assignment            1
#
#         Classification   Channel _merge
# 0           Short Haul    Direct   both
# 2            Mid Stage    Direct   both
# 7            Mid Stage    Direct   both
# 8            Long Haul    Direct   both
# 10                 Sun    Direct   both
# ...                ...       ...    ...
# 183992       Long Haul  InDirect   both
# 184001       Long Haul    Direct   both
# 184005       Mid Stage    Direct   both
# 184006       Mid Stage    Direct   both
# 184007       Long Haul    Direct   both
#
# [67966 rows x 31 columns]

# %%
snowflake_only
# Out:
#         Source Flight Date  Reservation Nmbr  Sked Detail Id Nmbr Departure  \
# 1       Amelia  2023-07-01           7898050               109353     YVR
# 3       Amelia  2023-07-01           7899691               124552     YVR
# 4       Amelia  2023-07-01           7872054               144182     YOW
# 5       Amelia  2023-07-01           7760232               151305     YYC
# 6       Amelia  2023-07-01           7801649               102675     YVR
# ...        ...         ...               ...                  ...       ...
# 184000  Amelia  2023-07-01           7973763               105136     YOW
# 184002  Amelia  2023-07-01           6050101               124444     YYZ
# 184003  Amelia  2023-07-01           7380537               108863     YOW
# 184004  Amelia  2023-07-01           7380643               105270     YKF
# 184008  Amelia  2023-07-01           7718720               147422     YUL
#
#        Arrival  Legs Id Nmbr  Charge Type  Net Charge  Taxes  ...  \
# 1        YYZ        16224362            1      -25.00  -1.25  ...
# 3        PVR        16227737            5      -25.91   0.00  ...
# 4        YHZ        16169781         1002       69.00   8.97  ...
# 5        YXX        15936924            5       -7.12  -0.36  ...
# 6        YUL        16023285            4     -254.78 -12.74  ...
# ...        ...           ...          ...         ...    ...  ...
# 184000   YYJ        16381426         1002       83.00   4.15  ...
# 184002   CUN        12411133         1000        0.00   0.00  ...
# 184003   YYC        15193216            5        7.12   0.93  ...
# 184004   YHZ        15193456            5        7.12   1.07  ...
# 184008   YHZ        15861792            5        7.12   1.07  ...
#
#           Agency Name               Sale_Username    Transborder Leg Status  \
# 1       Air Black Box              Administration       Domestic          X
# 3       Air Black Box              Administration  International          X
# 4       Air Black Box                      ABBAPI       Domestic          X
# 5       Air Black Box              Administration       Domestic          X
# 6       Air Black Box              Administration       Domestic          X
# ...               ...                         ...            ...        ...
# 184000  Air Black Box                      ABBAPI       Domestic          X
# 184002      Flair Air  BaseCC-PH - Ruel Velasquez  International          X
# 184003  Air Black Box                      ABBAPI       Domestic          X
# 184004  Air Black Box                      ABBAPI       Domestic          X
# 184008  Air Black Box                      ABBAPI       Domestic          X
#
#          Category              AncillaryCategory  PurchaseCnt  Classification  \
# 1        FlowThru        Airport Improvement Fee            0       Long Haul
# 3        FlowThru  Air Traveller Security Charge            0             Sun
# 4       Ancillary                   Basic Bundle            1       Mid Stage
# 5        FlowThru  Air Traveller Security Charge            0      Short Haul
# 6            Base                           Fare            0       Long Haul
# ...           ...                            ...          ...             ...
# 184000  Ancillary                   Basic Bundle            1       Long Haul
# 184002  Ancillary                Call Center Fee            1             Sun
# 184003   FlowThru  Air Traveller Security Charge            0       Long Haul
# 184004   FlowThru  Air Traveller Security Charge            0       Mid Stage
# 184008   FlowThru  Air Traveller Security Charge            0       Mid Stage
#
#        Channel     _merge
# 1       Direct  left_only
# 3       Direct  left_only
# 4       Direct  left_only
# 5       Direct  left_only
# 6       Direct  left_only
# ...        ...        ...
# 184000  Direct  left_only
# 184002  Direct  left_only
# 184003  Direct  left_only
# 184004  Direct  left_only
# 184008  Direct  left_only
#
# [116043 rows x 31 columns]

# %%
test2 = report_only[(report_only['Legs Id Nmbr'] ==14656731) & (report_only['Charge Type'] == 1)]

# %%
#str(test1["Percent of Full Leg"]) == str(test2["Percent of Full Leg"])

# %%
def calculate_accuracy(df1, df2):
    merged = df1.merge(df2, how = 'outer', indicator = True)
    matched = merged[merged['_merge'] == "both"]

    # Calculate the total number of elements
    total_elements = len(df2)

    # Calculate accuracy as a percentage
    accuracy = (len(matched) / total_elements) * 100

    return accuracy

# %%
accuracy_percentage = calculate_accuracy(snowflake_pd_df, report_df)
print(f"Accuracy: {accuracy_percentage:.2f}%")
# Out:
# Accuracy: 80.83%

# %% [markdown]
# # Output the difference file

# %%
try:
    snowflake_only.to_csv("snowflake_only_record.csv", index=False) 
except:
    print("No snowflake only records")
try:
    report_only.to_csv("report_only_record.csv", index=False) 
except:
    print("No report only records")
