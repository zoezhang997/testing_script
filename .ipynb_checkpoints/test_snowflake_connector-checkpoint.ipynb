# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import *
from snowflake.snowpark.functions import col, lit
import getpass
import pandas as pd
import json

# %%
password = getpass.getpass()    # SNOWFLAKE-PASSWORD
# Out:
# ········

# %%
#!pip install "snowflake-connector-python[pandas]"

# %%
connection_parameters = {
    "account": 'flyflair-datadepot',
    "user": 'zoe_zhang',
    "password": password,
    "role": "ACCOUNTADMIN"
}

session = Session.builder.configs(connection_parameters).create()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\network.py:1037, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout)
#    1034 # socket timeout is constant. You should be able to receive
#    1035 # the response within the time. If not, ConnectReadTimeout or
#    1036 # ReadTimeout is raised.
# -> 1037 raw_ret = session.request(
#    1038     method=method,
#    1039     url=full_url,
#    1040     headers=headers,
#    1041     data=input_data,
#    1042     timeout=socket_timeout,
#    1043     verify=True,
#    1044     stream=is_raw_binary,
#    1045     auth=SnowflakeAuth(token),
#    1046 )
#    1047 download_end_time = get_time_millis()
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\vendored\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\vendored\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\vendored\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\ssl_wrap_socket.py:79, in ssl_wrap_socket_with_ocsp(*args, **kwargs)
#      77 ret = ssl_.ssl_wrap_socket(*args, **kwargs)
# ---> 79 from .ocsp_asn1crypto import SnowflakeOCSPAsn1Crypto as SFOCSP
#      81 log.debug(
#      82     "OCSP Mode: %s, " "OCSP response cache file name: %s",
#      83     FEATURE_OCSP_MODE.name,
#      84     FEATURE_OCSP_RESPONSE_CACHE_FILE_NAME,
#      85 )
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\ocsp_asn1crypto.py:49
#      48 from snowflake.connector.errors import RevocationCheckError
# ---> 49 from snowflake.connector.ocsp_snowflake import SnowflakeOCSP, generate_cache_key
#      51 with warnings.catch_warnings():
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\ocsp_snowflake.py:29
#      26 # We use regular requests and urlib3 when we reach out to do OCSP checks, basically in this very narrow
#      27 # part of the code where we want to call out to check for revoked certificates,
#      28 # we don't want to use our hardened version of requests.
# ---> 29 import requests as generic_requests
#      30 from asn1crypto.ocsp import CertId, OCSPRequest, SingleResponse
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\requests\__init__.py:48
#      47 try:
# ---> 48     from charset_normalizer import __version__ as charset_normalizer_version
#      49 except ImportError:
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\charset_normalizer\__init__.py:23
#       1 """
#       2 Charset-Normalizer
#       3 ~~~~~~~~~~~~~~
#    (...)
#      21 :license: MIT, see LICENSE for more details.
#      22 """
# ---> 23 from charset_normalizer.api import from_fp, from_path, from_bytes, normalize
#      24 from charset_normalizer.legacy import detect
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\charset_normalizer\api.py:10
#       9 from charset_normalizer.constant import TOO_SMALL_SEQUENCE, TOO_BIG_SEQUENCE, IANA_SUPPORTED
# ---> 10 from charset_normalizer.md import mess_ratio
#      11 from charset_normalizer.models import CharsetMatches, CharsetMatch
#
# AttributeError: partially initialized module 'charset_normalizer' has no attribute 'md__mypyc' (most likely due to a circular import)
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\connection.py:1153, in SnowflakeConnection._authenticate(self, auth_instance)
#    1152 try:
# -> 1153     auth.authenticate(
#    1154         auth_instance=auth_instance,
#    1155         account=self.account,
#    1156         user=self.user,
#    1157         database=self.database,
#    1158         schema=self.schema,
#    1159         warehouse=self.warehouse,
#    1160         role=self.role,
#    1161         passcode=self._passcode,
#    1162         passcode_in_password=self._passcode_in_password,
#    1163         mfa_callback=self._mfa_callback,
#    1164         password_callback=self._password_callback,
#    1165         session_parameters=self._session_parameters,
#    1166     )
#    1167 except OperationalError as e:
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\auth\_auth.py:250, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     249 try:
# --> 250     ret = self._rest._post_request(
#     251         url,
#     252         headers,
#     253         json.dumps(body),
#     254         timeout=auth_timeout,
#     255         socket_timeout=auth_timeout,
#     256     )
#     257 except ForbiddenError as err:
#     258     # HTTP 403
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\network.py:720, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, _no_results, no_retry, socket_timeout, _include_retry_params)
#     718     pprint(ret)
# --> 720 ret = self.fetch(
#     721     "post",
#     722     full_url,
#     723     headers,
#     724     data=body,
#     725     timeout=timeout,
#     726     token=token,
#     727     no_retry=no_retry,
#     728     socket_timeout=socket_timeout,
#     729     _include_retry_params=_include_retry_params,
#     730 )
#     731 logger.debug(
#     732     "ret[code] = {code}, after post request".format(
#     733         code=(ret.get("code", "N/A"))
#     734     )
#     735 )
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\network.py:818, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     817 while True:
# --> 818     ret = self._request_exec_wrapper(
#     819         session, method, full_url, headers, data, retry_ctx, **kwargs
#     820     )
#     821     if ret is not None:
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\network.py:941, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     940 if not no_retry:
# --> 941     raise e
#     942 logger.debug("Ignored error", exc_info=True)
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\network.py:861, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     860 try:
# --> 861     return_object = self._request_exec(
#     862         session=session,
#     863         method=method,
#     864         full_url=full_url,
#     865         headers=headers,
#     866         data=data,
#     867         token=token,
#     868         **kwargs,
#     869     )
#     870     if return_object is not None:
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\network.py:1117, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout)
#    1112     logger.debug(
#    1113         "Hit a timeout error while logging in. Will be handled by "
#    1114         f"authenticator. Ignore the following. Error stack: {err}",
#    1115         exc_info=True,
#    1116     )
# -> 1117     raise OperationalError(
#    1118         msg="ConnectionTimeout occurred. Will be handled by authenticator",
#    1119         errno=ER_CONNECTION_TIMEOUT,
#    1120     )
#    1121 else:
#
# OperationalError: 251011: ConnectionTimeout occurred. Will be handled by authenticator
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 8
#       1 connection_parameters = {
#       2     "account": 'flyflair-datadepot',
#       3     "user": 'zoe_zhang',
#       4     "password": password,
#       5     "role": "ACCOUNTADMIN"
#       6 }
# ----> 8 session = Session.builder.configs(connection_parameters).create()
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\snowpark\session.py:293, in Session.SessionBuilder.create(self)
#     291 def create(self) -> "Session":
#     292     """Creates a new Session."""
# --> 293     session = self._create_internal(self._options.get("connection"))
#     294     return session
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\snowpark\session.py:313, in Session.SessionBuilder._create_internal(self, conn)
#     310 if "paramstyle" not in self._options:
#     311     self._options["paramstyle"] = "qmark"
#     312 new_session = Session(
# --> 313     ServerConnection({}, conn) if conn else ServerConnection(self._options),
#     314     self._options,
#     315 )
#     317 if "password" in self._options:
#     318     self._options["password"] = None
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:136, in ServerConnection.__init__(self, options, conn)
#     134 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     135 self._add_application_name()
# --> 136 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     137 if "password" in self._lower_case_parameters:
#     138     self._lower_case_parameters["password"] = None
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\__init__.py:51, in Connect(**kwargs)
#      50 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 51     return SnowflakeConnection(**kwargs)
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\connection.py:319, in SnowflakeConnection.__init__(self, **kwargs)
#     317 self.query_context_cache_size = 5
#     318 self.__set_error_attributes()
# --> 319 self.connect(**kwargs)
#     320 self._telemetry = TelemetryClient(self._rest)
#     322 # get the imported modules from sys.modules
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\connection.py:590, in SnowflakeConnection.connect(self, **kwargs)
#     588         connection_diag.generate_report()
#     589 else:
# --> 590     self.__open_connection()
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\connection.py:860, in SnowflakeConnection.__open_connection(self)
#     856 else:
#     857     # okta URL, e.g., https://<account>.okta.com/
#     858     self.auth_class = AuthByOkta(application=self.application)
# --> 860 self.authenticate_with_retry(self.auth_class)
#     862 self._password = None  # ensure password won't persist
#     863 self.auth_class.reset_secrets()
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\connection.py:1127, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1124 def authenticate_with_retry(self, auth_instance) -> None:
#    1125     # make some changes if needed before real __authenticate
#    1126     try:
# -> 1127         self._authenticate(auth_instance)
#    1128     except ReauthenticationRequest as ex:
#    1129         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1130         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\connection.py:1198, in SnowflakeConnection._authenticate(self, auth_instance)
#    1196 except OperationalError as auth_op:
#    1197     if auth_op.errno == ER_FAILED_TO_CONNECT_TO_DB:
# -> 1198         raise auth_op from e
#    1199     logger.debug("Continuing authenticator specific timeout handling")
#    1200     continue
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\connection.py:1175, in SnowflakeConnection._authenticate(self, auth_instance)
#    1173 while True:
#    1174     try:
# -> 1175         auth_instance.handle_timeout(
#    1176             authenticator=self._authenticator,
#    1177             service_name=self.service_name,
#    1178             account=self.account,
#    1179             user=self.user,
#    1180             password=self._password,
#    1181         )
#    1182         auth.authenticate(
#    1183             auth_instance=auth_instance,
#    1184             account=self.account,
#    (...)
#    1194             session_parameters=self._session_parameters,
#    1195         )
#    1196     except OperationalError as auth_op:
#
# File ~\AppData\Local\anaconda3\envs\python38\lib\site-packages\snowflake\connector\auth\by_plugin.py:219, in AuthByPlugin.handle_timeout(***failed resolving arguments***)
#     213     error = OperationalError(
#     214         msg=f"Could not connect to Snowflake backend after {self._retry_ctx.get_current_retry_count()} attempt(s)."
#     215         "Aborting",
#     216         errno=ER_FAILED_TO_CONNECT_TO_DB,
#     217     )
#     218     self._retry_ctx.reset()
# --> 219     raise error
#     220 else:
#     221     logger.debug(
#     222         f"Hit connection timeout, attempt number {self._retry_ctx.get_current_retry_count()}."
#     223         " Will retry in a bit..."
#     224     )
#
# OperationalError: 250001: Could not connect to Snowflake backend after 1 attempt(s).Aborting

# %%
connection_parameters["database"] = 'ANALYTICS_PROD'
connection_parameters["schema"] = ' IOATAWARE'
connection_parameters["warehouse"] = 'COMPUTE_WH'
with open('creds.json', 'w') as outfile:
        outfile.write(json.dumps(connection_parameters))

# %%
with open('creds.json') as f:
    connection_parameters = json.load(f)

# %%
session = Session.builder.configs(connection_parameters).create()
print(f"Current Database and schema: {session.get_fully_qualified_current_schema()}")
print(f"Current Warehouse: {session.get_current_warehouse()}")
# Out:
# Current Database and schema: "ANALYTICS_PROD"." IOATAWARE"
# Current Warehouse: "COMPUTE_WH"

# %%
snowpark_df = session.table('ANALYTICS_PROD.IOATAWARE.VW_AIF_REPORT_DETAIL')

# %%
snowflake_pd_df = snowpark_df.filter(col("Flight Date") == '2023/07/01').limit(10).to_pandas()

# %%
report_df = pd.read_csv('Report_ADD.csv')

# %%
snowflake_pd_df.head()
# Out:
#   Flight Date Departure Arrival  Reservation Number  Leg Number     PNR  \
# 0  2023/07/01     YKF     YHZ               7549160           1  RAKH25
# 1  2023/07/01     YVR     YKF               7887937           2  VMG8GJ
# 2  2023/07/01     YEG     YYZ               7619882           1  3CCM2Q
# 3  2023/07/01     YYZ     YSJ               7551112           2  CZF2XH
# 4  2023/07/01     YXX     YEG               7996706           1  7ASGS5
#
#   Check In Boarded Status                                    First Name  \
# 0                B      C  7h/6zU9U1uBFU2UBk9SpKsM1wVyu24sjuz170D8I/aw=
# 1                B      C  08xUz+v9pR3o5qYK34b6TY0jGJxqZNFLJ82hBvLafSo=
# 2                B      C  P1WsQre1Hzr10+AAnzg71AkhppfKXw2a+tzOCqhiZMI=
# 3                B      C  CFUeWTEKER1uQat71M5v5Ve8tPs2V/kcKYJnxbkq6gM=
# 4                B      C  06db8xIw6MGipxB79qCaJ66yEcXWKX1uupAOkylFvKI=
#
#                                       Last Name              Charge Type  \
# 0  dVIyNI5OcVNzgmt18+1Pb3h8bf0Jr11NVx7dXQFdmNA=  Airport Improvement Fee
# 1  XNU896lEbPqT3kgLckN5RH7KCho1O3TwY8Lkc7rmFuI=  Airport Improvement Fee
# 2  VBkwiK7Juwos/itDy1eHbuKdObyMBDw0rIeHw4oMMHo=  Airport Improvement Fee
# 3  U12YY4ZwCc2oM+YRM8O15Lcar9X54nfNstecIAhTt1Y=  Airport Improvement Fee
# 4  18acgeiRB/0H/10Y+BDvJiLFAyWFNAsqrYYLzS4Rffs=  Airport Improvement Fee
#
#    Net Charge Leg Start Leg End Charge Date
# 0        15.0     YKF     YHZ    05/16/2023
# 1        25.0     YVR     YKF    06/13/2023
# 2        35.0     YEG     YYZ    05/23/2023
# 3        35.0     YYZ     YSJ    05/16/2023
# 4         0.0     YXX     YEG    06/24/2023

# %%
report_df.head()
# Out:
#                    ExecutionTime2                ExecutionTime3  Unnamed: 2  \
# 0  Flight Start Date: Jul 1, 2023  Flight End Date: Jul 1, 2023         NaN
# 1                             NaN                           NaN         NaN
# 2                     FlightDate1               str_Flight_Nmbr  Departure1
# 3                        7/1/2023                           557       YOW
# 4                        7/1/2023                           557       YOW
#
#   Unnamed: 3            Unnamed: 4            Unnamed: 5 Unnamed: 6  \
# 0        NaN                   NaN                   NaN        NaN
# 1        NaN                   NaN                   NaN        NaN
# 2   Arrival1  lng_Reservation_Nmbr  lng_Res_Legs_Id_Nmbr        PNR
# 3      YYC                 4465833               9050043     MSDEXN
# 4      YYC                 4465833               9050044     MSDEXN
#
#                 Unnamed: 7      Unnamed: 8      Unnamed: 9    Unnamed: 10  \
# 0                      NaN             NaN             NaN            NaN
# 1                      NaN             NaN             NaN            NaN
# 2  str_Res_CheckIn_Boarded  str_Res_Status  str_First_Name  str_Last_Name
# 3                        B               C          TAMARA         JUMAAH
# 4                        B               C        ESTEPHAN         HINDYA
#
#                Unnamed: 11 Unnamed: 12   Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0                      NaN         NaN           NaN         NaN         NaN
# 1                      NaN         NaN           NaN         NaN         NaN
# 2  str_GL_Charge_Type_Desc   NetCharge  LegDeparture  LegArrival  ChargeDate
# 3  Airport Improvement Fee      $35.00         YOW         YYC     9/11/2022
# 4  Airport Improvement Fee      $35.00         YOW         YYC     9/11/2022
