# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import *
from snowflake.snowpark.functions import col, lit
import getpass
import pandas as pd
import json
from get_secret import get_secret

# %%
connection_parameters = json.loads(get_secret())
connection_parameters.update({'warehouse':'COMPUTE_WH', 'database':'ANALYTICS_PROD','schema': 'IOATAWARE',"loglevel":'DEBUG'})
session = Session.builder.configs(connection_parameters).create()

# %%
print(f"Current Database and schema: {session.get_fully_qualified_current_schema()}")
print(f"Current Warehouse: {session.get_current_warehouse()}")
# Out:
# Current Database and schema: "ANALYTICS_PROD"."IOATAWARE"
# Current Warehouse: "COMPUTE_WH"

# %%
snowpark_df = session.table('ANALYTICS_PROD.IOATAWARE.VW_AIF_REPORT_DETAIL')
snowflake_pd_df = snowpark_df.filter(col("Flight Date") == '2023/07/01').to_pandas()

# %%
report_df = pd.read_csv('Report_ADD.csv')

# %%
snowflake_pd_df.head()
# Out:
#   Flight Date Departure Arrival  Reservation Number  Leg Number     PNR  \
# 0  2023/07/01     YYC     YLW               7605501           1  XAJXBZ
# 1  2023/07/01     YYC     YXX               7399891           1  HQZ5C4
# 2  2023/07/01     YHZ     YUL               7118082           1  UPQMGN
# 3  2023/07/01     YXX     YEG               8028691           1  US9288
# 4  2023/07/01     YEG     YLW               6315258           1  VBGXUF
#
#   Check In Boarded Status                                    First Name  \
# 0                B      C  JvdoZhQ/29fWY0HFwWbCReKb5Wqkj6/BKiH4zp92JHo=
# 1                B      C  4VPlajgoKh9iV2nqxSav1IFlU80lm77WFD11SYNI+I8=
# 2                B      C  hEA2P39zaPZI7AEby3xujmCanCSX/kaJvDlyZQ2d8JA=
# 3                B      C  lYYf0O0hju6GLvniL2IjCz6NRo+i7rGlJFpuXWKGrzo=
# 4                B      C  gsBijb5Zb/zamC6JxAgGPMvS4LgmscDB3cLVfSRbpvU=
#
#                                       Last Name              Charge Type  \
# ...

# %%
report_df
# Out:
#                        ExecutionTime2                ExecutionTime3  \
# 0      Flight Start Date: Jul 1, 2023  Flight End Date: Jul 1, 2023
# 1                                 NaN                           NaN
# 2                         FlightDate1               str_Flight_Nmbr
# 3                            7/1/2023                           557
# 4                            7/1/2023                           557
# ...                               ...                           ...
# 13195                        7/1/2023                           550
# 13196                        7/1/2023                           550
# 13197                        7/1/2023                           600
# 13198                        7/1/2023                           600
# 13199                        7/1/2023                           760
#
#        Unnamed: 2 Unnamed: 3            Unnamed: 4            Unnamed: 5  \
# 0             NaN        NaN                   NaN                   NaN
# ...

# %%
report_df.iloc[2:]
# Out:
#       ExecutionTime2   ExecutionTime3  Unnamed: 2 Unnamed: 3  \
# 2        FlightDate1  str_Flight_Nmbr  Departure1   Arrival1
# 3           7/1/2023              557       YOW        YYC
# 4           7/1/2023              557       YOW        YYC
# 5           7/1/2023              557       YOW        YYC
# 6           7/1/2023              557       YOW        YYC
# ...              ...              ...         ...        ...
# 13195       7/1/2023              550       YLW        YYC
# 13196       7/1/2023              550       YLW        YYC
# 13197       7/1/2023              600       YVR        YYZ
# 13198       7/1/2023              600       YVR        YYZ
# 13199       7/1/2023              760       YLW        YEG
#
#                  Unnamed: 4            Unnamed: 5 Unnamed: 6  \
# 2      lng_Reservation_Nmbr  lng_Res_Legs_Id_Nmbr        PNR
# 3                   4465833               9050043     MSDEXN
# 4                   4465833               9050044     MSDEXN
# ...
